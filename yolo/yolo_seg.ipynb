# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
results = model(source='bus.jpg', save=True)
results
# Out:
# ...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 18.4MB/s]
# image 1/1 /home/kth/robot_dev/yolo/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 48.2ms
# Speed: 2.3ms preprocess, 48.2ms inference, 131.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
results = model(source='zidane.jpg', save=True)
results
# Out:
# image 1/1 /home/kth/robot_dev/yolo/zidane.jpg: 384x640 2 persons, 1 tie, 62.7ms
# Speed: 20.0ms preprocess, 62.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
model = YOLO('yolov8n-seg.pt')
results = model.train(data='coco8-seg.yaml', epochs=100, imgsz=400)
# Out:
# New https://pypi.org/project/ultralytics/8.3.141 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.140 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 5920MiB)
# ...

# %%
model = YOLO('runs/segment/train/weights/best.pt')
results = model.predict(source="./ele.jpg", conf=0.2, save=True)
# Out:
# image 1/1 /home/kth/robot_dev/yolo/ele.jpg: 256x416 2 elephants, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/segment/predict3
