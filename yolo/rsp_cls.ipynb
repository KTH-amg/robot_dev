# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')
results = model.predict(source="./rock-scissor-paper/rock.jpg", save=True)
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 12.7MB/s]
# image 1/1 /home/kth/robot_dev/yolo/rock-scissor-paper/rock.jpg: 224x224 computer_keyboard 0.81, notebook 0.08, space_bar 0.07, laptop 0.03, mouse 0.01, 2.1ms
# Speed: 11.2ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict

# %%
model = YOLO('yolov8n-cls.pt')
results = model.train(data='./rock-scissor-paper', epochs=3, imgsz=300)
# Out:
# Ultralytics 8.3.140 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 5920MiB)
# ...

# %%
model = YOLO('./runs/classify/train/weights/best.pt')
results = model.predict(source="./rock-scissor-paper/paper.jpg", save=True)
# Out:
# image 1/1 /home/kth/robot_dev/yolo/rock-scissor-paper/paper.jpg: 320x320 paper 0.45, rock 0.28, scissors 0.27, 2.6ms
# Speed: 9.5ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/classify/predict4
