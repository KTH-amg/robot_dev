# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('./data/nintendo.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (651, 865, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('./data/nintendo.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
img.shape
# Out:
# (651, 865, 3)

# %%
new_img = cv2.resize(fix_img, (800, 600))
plt.imshow(new_img)

# %%
plt.imshow(cv2.flip(fix_img, 0))

# %%
plt.imshow(cv2.flip(fix_img, 1))

# %%
plt.imshow(cv2.flip(fix_img, -1))

# %%
cv2.imwrite('./data/nintendo_gray.jpg', img_gray)
# Out:
# True
