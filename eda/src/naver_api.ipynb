# %% [markdown]
# ## 네이버 API 연습

# %%
import os
import sys
import urllib.request

client_id = "cnmo6BfgBzkZhSHPunUH"
client_secret = "mWt10TxTbS"
encText = urllib.parse.quote("스플래툰 3")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 07 Mar 2025 09:54:22 +0900",
# 	"total":17630,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>스플래툰 3<\/b> 이치방쿠지 제2탄 G상 입욕제 사용기",
# 			"link":"https:\/\/blog.naver.com\/onejang80\/223741850392",
# 			"description":"왕년의 스플래툰 블로거(?)답게, 오랜만이지만 스플래툰 포스팅을 가져왔습니다. 아쉽지만 게임 관련은... 이상으로 &lt;<b>스플래툰 3<\/b> 이치방쿠지 제2탄 G상 입욕제 사용기&gt; 포스팅 마칩니다. 감사합니다!",
# 			"bloggername":"모두의 카제쿤",
# 			"bloggerlink":"blog.naver.com\/onejang80",
# 			"postdate":"20250130"
# 		},
# 		{
# 			"title":"프로콘(프로 컨트롤러) 후기 및 연결 방법 &amp; <b>스플래툰3<\/b> 시작",
# 			"link":"https:\/\/blog.naver.com\/berry2467\/223686643534",
# 			"description":"유튜버들이 플레이하는 거 보고 약 2달 전에 <b>스플래툰3<\/b>를 구매했다. 원래 이렇게 다른 사람들이랑 싸워서 이겨야 하는 게임 류는 잘 안하는 편인데 스플래툰은 단순히 싸운다기보다 굉장히 룰이 다양하기... ",
# 			"bloggername":"빛이 드는 도서관",
# 			"bloggerlink":"blog.naver.com\/berry2467",
# 			"postdate":"20241208"
# 		},
# 		{
# 			"title":"닌텐도 <b>스플래툰3<\/b> 스퀵 클린 숙련도 4성 달성 후기",
# ...

# %%
encText = urllib.parse.quote("스플래툰 3")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Fri, 07 Mar 2025 09:59:26 +0900",
# 	"total":1,
# 	"start":1,
# 	"display":1,
# 	"items":[
# 		{
# 			"title":"スプラトゥ-ン3 イカすア-トブック (스플래툰3 이카스 아트북)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/42076830393",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4207683\/42076830393.20250214072619.jpg",
# 			"author":"",
# 			"discount":"29500",
# 			"publisher":"KADOKAWA",
# 			"pubdate":"20230331",
# 			"isbn":"9784047336551",
# 			"description":""
# 		}
# 	]
# }

# %%
encText = urllib.parse.quote("스플래툰 3")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # JSON 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Fri, 07 Mar 2025 10:01:40 +0900",
# 	"total":30216,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>스플래툰<\/b> 아미보 피규어 모든 종류 수집해봤어요",
# 			"link":"http:\/\/cafe.naver.com\/paramsx\/594242",
# 			"description":"이번에는 <b>스플래툰<\/b> 아미보 피규어들 전종을 수집해봤어요! 중복도 한가득인 <b>스플래툰<\/b> 아미보 전종 올클입니다! 단품만 모으지 읺았고 세트품까지 모아봤어요 <b>스플래툰<\/b>1(걸 보이 그린스퀴드 아미보) <b>스플래툰<\/b>1의... ",
# 			"cafename":"구닥동",
# 			"cafeurl":"https:\/\/cafe.naver.com\/paramsx"
# 		},
# 		{
# 			"title":"지금 <b>스플래툰3<\/b> 사는건 늦은감이있나요 ??",
# 			"link":"http:\/\/cafe.naver.com\/ghdi58\/5878713",
# 			"description":"지루하구 .. 링피트 ..힘들고 .. 포켓몬 바이올렛 ..별로구 … 별의커비 디스커버리 오늘 와서 게임 해보려 하구요 !! <b>스플래툰3<\/b> 이것도 재밌을까 해서요ㅠㅠ 제가 재밌어할 게임 어디있을까요 하아 …",
# 			"cafename":"닌텐도 스위치 한국 커뮤니티[동물의숲...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/ghdi58"
# 		},
# 		{
# 			"title":"이번에 <b>스플래툰3<\/b> 샀어요!",
# 			"link":"http:\/\/cafe.naver.com\/wtac\/7442583",
# ...

# %%
encText = urllib.parse.quote("스플래툰 3")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Fri, 07 Mar 2025 10:02:13 +0900",
# 	"total":6094,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"닌텐도 스위치 <b>스플래툰3<\/b> 한글판 정품 게임 칩 팩",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/6942498842",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8448699\/84486999164.7.jpg",
# 			"lprice":"56800",
# 			"hprice":"",
# 			"mallName":"컴투스토어",
# 			"productId":"84486999164",
# 			"productType":"2",
# 			"brand":"닌텐도",
# 			"maker":"닌텐도",
# 			"category1":"디지털\/가전",
# 			"category2":"게임기\/타이틀",
# 			"category3":"게임타이틀",
# 			"category4":""
# 		},
# 		{
# 			"title":"닌텐도 <b>스플래툰3<\/b> 한글판(SWITCH)",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/34290492622",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3429049\/34290492622.20220826125915.jpg",
# 			"lprice":"40160",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"34290492622",
# 			"productType":"1",
# 			"brand":"닌텐도",
# 			"maker":"닌텐도",
# ...

# %%
encText = urllib.parse.quote("닌텐도 스위치")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # JSON 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Fri, 07 Mar 2025 10:04:40 +0900",
# 	"total":24,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>닌텐도 스위치<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=4356322&cid=59088&categoryId=59096",
# 			"description":"'<b>닌텐도 스위치<\/b>'는 가정용 콘솔게임기와 휴대용 게임기를 통합한 신개념 게임기다. TV 모드, 휴대 모드, 테이블 모드로 각각 게임을 즐길 수 있다. 출시와 동시에 좋은 반응을 보이며 닌텐도 부활 공",
# 			"thumbnail":"https:\/\/post-phinf.pstatic.net\/MjAxNzEyMTFfMjcg\/MDAxNTEyOTg3MTYwNTEz.ecB1LArpD5AIufxogKyQaOprIp4ZSppu7pR5GeukzF4g.h9WIbmj5e3qLFNIg2T6ixMggrUohhGoxWsD7rNvHnJcg.PNG\/I-CYykLFQSwtGBJ9V1mnhxes2678.jpg?type=w540_fst"
# 		},
# 		{
# 			"title":"<b>닌텐도 스위치<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=6710474&cid=40942&categoryId=32844",
# 			"description":"2017년 일본의 <b>닌텐도<\/b>에서 출시한 태블릿 형태의 콘솔 게임기이다. 2017년 3월 3일에 <b>닌텐도<\/b>에서 출시한 ‘위 유(Wii U)’와 ‘<b>닌텐도<\/b> 3DS’의 후속작이다. 태블릿 형태의 콘솔로, 본체 스탠드를 세우고 ",
# ...

# %% [markdown]
# ## 몰스킨 쇼핑 정보 취득

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)

    return base + node + param_query + param_start + param_disp

# %%
gen_search_url('shop', 'TEST', 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %%
import json
import datetime

def get_result_orange(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    response = urllib.request.urlopen(request)

    print("[%s] Url Response Success" % datetime.datetime.now())

    return json.loads(response.read().decode('utf-8'))

# %%
client_id = "cnmo6BfgBzkZhSHPunUH"
client_secret = "mWt10TxTbS"

url = gen_search_url('shop', '몰스킨', 1, 5)
one_result = get_result_orange(url)
# Out:
# [2025-03-07 10:35:57.962273] Url Response Success

# %%
one_result
# Out:
# {'lastBuildDate': 'Fri, 07 Mar 2025 10:35:57 +0900',
#  'total': 46150,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '[<b>몰스킨</b>] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)',
#    'link': 'http://www.moleskine.co.kr/index.html?branduid=2557327&ref=naver_open',
#    'image': 'https://shopping-phinf.pstatic.net/main_5006626/50066265686.jpg',
#    'lprice': '16200',
#    'hprice': '',
#    'mallName': '몰스킨공식온라인스토어',
#    'productId': '50066265686',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 클래식노트 하드커버',
#    'link': 'https://search.shopping.naver.com/catalog/46221773618',
#    'image': 'https://shopping-phinf.pstatic.net/main_4622177/46221773618.20240306165408.jpg',
#    'lprice': '28800',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '46221773618',
#    'productType': '1',
#    'brand': '몰스킨',
# ...

# %%
one_result['items'][0]['title']
# Out:
# '[<b>몰스킨</b>] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)'

# %%
one_result['items'][0]['lprice']
# Out:
# '16200'

# %%
one_result['items'][0]['mallName']
# Out:
# '몰스킨공식온라인스토어'

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")

    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]

    result_pd = pd.DataFrame({'title':title, 'lprice':lprice,
                              'hprice':hprice, 'link':link,
                              'mall':mall_name},
                              columns=['title', 'lprice', 'hprice', 'link', 'mall'])
    
    return result_pd

# %%
pd_result = get_fields(one_result)

# %%
pd_result
# Out:
#                                          title  lprice hprice  \
# 0  [몰스킨] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)   16200
# 1                               몰스킨 클래식노트 하드커버   28800
# 2                 [백화점] 폴로 랄프로렌 남성 몰스킨 유틸리티 자켓  329000
# 3       로이텀 2025 다이어리 위클리&amp;노트 소프트커버 하드커버 A5   25200
# 4                       몰스킨 2025 위클리 다이어리 상품선택   18000
#
#                                                 link         mall
# 0  http://www.moleskine.co.kr/index.html?branduid...  몰스킨공식온라인스토어
# 1  https://search.shopping.naver.com/catalog/4622...          네이버
# 2  https://smartstore.naver.com/main/products/113...         제이어드
# 3  https://smartstore.naver.com/main/products/108...       몰스킨스토어
# 4  https://search.shopping.naver.com/catalog/5101...          네이버

# %%
result_mol = []

for n in range(1, 1000, 100):
    url = gen_search_url('shop', '"스플래툰 3"', n, 100)
    json_result = get_result_orange(url)
    pd_result = get_fields(json_result)

    result_mol.append(pd_result)

result_mol = pd.concat(result_mol)
# Out:
# [2025-03-07 11:10:51.375499] Url Response Success
# [2025-03-07 11:10:51.616047] Url Response Success
# [2025-03-07 11:10:51.857289] Url Response Success
# [2025-03-07 11:10:52.095983] Url Response Success
# [2025-03-07 11:10:52.338093] Url Response Success
# [2025-03-07 11:10:52.579977] Url Response Success
# [2025-03-07 11:10:52.827828] Url Response Success
# [2025-03-07 11:10:53.073179] Url Response Success
# [2025-03-07 11:10:53.322051] Url Response Success
# [2025-03-07 11:10:53.588479] Url Response Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 46.9+ KB

# %%
result_mol.reset_index(drop=True, inplace=True)
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
result_mol.head()
# Out:
#                                            title lprice hprice  \
# 0                          닌텐도 스플래툰3 한글판(SWITCH)  40240
# 1                    닌텐도 스위치 스플래툰3 한글판 정품 게임 칩 팩  56800
# 2                닌텐도 스위치 스플래툰3 다운로드코드패키지 스플래툰3DL  44800
# 3                 닌텐도 스위치 스플래툰3 슈팅건 그립 세트 게임 칩 팩  65000
# 4  닌텐도 스위치 스플래툰3 익스팬션 패스 확장판 DLC 오더폴리스 시티 사이드 오더  23800
#
#                                                 link   mall
# 0  https://search.shopping.naver.com/catalog/3429...    네이버
# 1  https://smartstore.naver.com/main/products/694...  컴투스토어
# 2  https://smartstore.naver.com/main/products/712...  컴투스토어
# 3  https://smartstore.naver.com/main/products/728...    에드몰
# 4  https://smartstore.naver.com/main/products/827...    온노리

# %%
result_mol['hprice'] = result_mol['hprice'].replace('', '0')

result_mol['lprice'] = result_mol['lprice'].astype('float')
result_mol['hprice'] = result_mol['hprice'].astype('float')
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   hprice  1000 non-null   float64
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
writer = pd.ExcelWriter('../data/splatoon_3_in_naver_shop.xlsx',
                        engine='xlsxwriter')
result_mol.to_excel(writer, sheet_name='Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A', 4)
worksheet.set_column('B:B', 65)
worksheet.set_column('C:C', 10)
worksheet.set_column('D:D', 10)
worksheet.set_column('E:E', 50)
worksheet.set_column('F:F', 15)

worksheet.conditional_format('C2:C1001', {'type':'3_color_scale'})

writer.close()
