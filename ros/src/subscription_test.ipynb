# %%
import rclpy as rp
from turtlesim.msg import Pose

# %%
rp.init()
test_node = rp.create_node('sub_test')

# %%
cnt = 0

def callback(data):
    global cnt
    cnt += 1
    print(">", cnt, " -> X : ", data.x, ", Y : ", data.y)
    if cnt>3:
        raise Exception("Subscription stop")

# %%
test_node.create_subscription(Pose, "/turtle1/pose", callback, 10)

# %%
rp.spin(test_node)
# Out:
# --->
# /turtle1/pose :  turtlesim.msg.Pose(x=5.544444561004639, y=5.544444561004639, theta=0.0, linear_velocity=0.0, angular_velocity=0.0)
# X :  5.544444561004639
# Y :  5.544444561004639
# Theta :  0.0
# > 1  -> X :  5.544444561004639 , Y :  5.544444561004639
# --->
# /turtle1/pose :  turtlesim.msg.Pose(x=5.544444561004639, y=5.544444561004639, theta=0.0, linear_velocity=0.0, angular_velocity=0.0)
# X :  5.544444561004639
# Y :  5.544444561004639
# Theta :  0.0
# > 2  -> X :  5.544444561004639 , Y :  5.544444561004639
# --->
# /turtle1/pose :  turtlesim.msg.Pose(x=5.544444561004639, y=5.544444561004639, theta=0.0, linear_velocity=0.0, angular_velocity=0.0)
# X :  5.544444561004639
# Y :  5.544444561004639
# Theta :  0.0
# > 3  -> X :  5.544444561004639 , Y :  5.544444561004639
# --->
# /turtle1/pose :  turtlesim.msg.Pose(x=5.544444561004639, y=5.544444561004639, theta=0.0, linear_velocity=0.0, angular_velocity=0.0)
# X :  5.544444561004639
# Y :  5.544444561004639
# Theta :  0.0
# > 4  -> X :  5.544444561004639 , Y :  5.544444561004639
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rp.spin(test_node)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/__init__.py:244, in spin(node, executor)
#     242     executor.add_node(node)
#     243     while executor.context.ok():
# --> 244         executor.spin_once()
#     245 finally:
#     246     executor.remove_node(node)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/executors.py:839, in SingleThreadedExecutor.spin_once(self, timeout_sec)
#     838 def spin_once(self, timeout_sec: Optional[float] = None) -> None:
# --> 839     self._spin_once_impl(timeout_sec)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/executors.py:834, in SingleThreadedExecutor._spin_once_impl(self, timeout_sec, wait_condition)
#     832 handler()
#     833 if handler.exception() is not None:
# --> 834     raise handler.exception()
#     836 handler.result()
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/task.py:269, in Task.__call__(self)
#     266 if inspect.iscoroutine(self._handler):
#     267     # Execute a coroutine
#     268     try:
# --> 269         self._handler.send(None)
#     270     except StopIteration as e:
#     271         # The coroutine finished; store the result
#     272         self.set_result(e.value)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/executors.py:518, in Executor._make_handler.<locals>.handler(entity, gc, is_shutdown, work_tracker)
#     516 try:
#     517     if call_coroutine is not None:
# --> 518         await call_coroutine()
#     519 finally:
#     520     entity.callback_group.ending_execution(entity)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/executors.py:406, in Executor._take_subscription.<locals>._execute()
#     405 async def _execute():
# --> 406     await await_or_execute(sub.callback, *msg_tuple)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/rclpy/executors.py:111, in await_or_execute(callback, *args)
#     108     return await callback(*args)
#     109 else:
#     110     # Call a normal function
# --> 111     return callback(*args)
#
# Cell In[10], line 8, in callback(data)
#       6 print(">", cnt, " -> X : ", data.x, ", Y : ", data.y)
#       7 if cnt>3:
# ----> 8     raise Exception("Subscription stop")
#
# Exception: Subscription stop
